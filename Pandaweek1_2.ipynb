# %% [markdown]
# <a href="https://colab.research.google.com/github/Desmyk/PYDATA/blob/main/Pandaweek1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
# Create your time range (start and end variables).
# The start date should be 01/01/2015 and the end should today (whatever your today is).

from datetime import date

today = date.today()

# Define the start and end dates
start_date = date(2015, 1, 1)
end_date = today

# Print the dates
print(f"Start date: {start_date}")
print(f"End date: {end_date}")
# Out:
# Start date: 2015-01-01
# End date: 2024-04-19

# %%
# Get an API key for one of the APIs that are supported by Pandas Datareader, preferably for AlphaVantage.

import pandas_datareader.data as web

api_key = "HFQZ62XLBEZQXFYT"

# Get data from Alpha Vantage
data = web.DataReader("MSFT", data_source="av-daily", api_key=api_key, start=start_date, end=end_date)

data
# Out:
#               open      high       low    close    volume
# 2015-01-02   46.66   47.4200   46.5400   46.760  27913852
# 2015-01-05   46.37   46.7300   46.2500   46.325  39673865
# 2015-01-06   46.38   46.7490   45.5400   45.650  36447854
# 2015-01-07   45.98   46.4600   45.4900   46.230  29114061
# 2015-01-08   46.75   47.7499   46.7200   47.590  29645202
# ...            ...       ...       ...      ...       ...
# 2024-04-12  424.05  425.1794  419.7700  421.900  19253750
# 2024-04-15  426.60  426.8200  413.4300  413.640  20273538
# 2024-04-16  414.57  418.4000  413.7301  414.580  16765616
# 2024-04-17  417.25  418.8800  410.3300  411.840  15855485
# 2024-04-18  410.63  411.8900  403.9500  404.270  21029917
#
# [2339 rows x 5 columns]

# %%
#  Use Pandas Datarader to read the daily time series for the Apple stock (ticker symbol AAPL) between 01/01/2015 and today,
#assign it to df_apple and print it.

import pandas_datareader.data as web

api_key = "HFQZ62XLBEZQXFYT"

# Get data from Alpha Vantage
df_apple = web.DataReader("AAPL", data_source="av-daily", api_key=api_key, start=start_date, end=end_date)

df_apple
# Out:
#               open    high      low   close     volume
# 2015-01-02  111.39  111.44  107.350  109.33   53204626
# 2015-01-05  108.29  108.65  105.410  106.25   64285491
# 2015-01-06  106.54  107.43  104.630  106.26   65797116
# 2015-01-07  107.20  108.20  106.695  107.75   40105934
# 2015-01-08  109.23  112.15  108.700  111.89   59364547
# ...            ...     ...      ...     ...        ...
# 2024-04-12  174.26  178.36  174.210  176.55  101670886
# 2024-04-15  175.36  176.63  172.500  172.69   73531773
# 2024-04-16  171.75  173.76  168.270  169.38   73711235
# 2024-04-17  169.61  170.65  168.000  168.00   50901210
# 2024-04-18  168.03  168.64  166.550  167.04   43122903
#
# [2339 rows x 5 columns]

# %%
# Add a new column "stock" and add the ticker symbol

df_apple["stock"] = "AAPL"

df_apple
# Out:
#               open    high      low   close     volume stock
# 2015-01-02  111.39  111.44  107.350  109.33   53204626  AAPL
# 2015-01-05  108.29  108.65  105.410  106.25   64285491  AAPL
# 2015-01-06  106.54  107.43  104.630  106.26   65797116  AAPL
# 2015-01-07  107.20  108.20  106.695  107.75   40105934  AAPL
# 2015-01-08  109.23  112.15  108.700  111.89   59364547  AAPL
# ...            ...     ...      ...     ...        ...   ...
# 2024-04-12  174.26  178.36  174.210  176.55  101670886  AAPL
# 2024-04-15  175.36  176.63  172.500  172.69   73531773  AAPL
# 2024-04-16  171.75  173.76  168.270  169.38   73711235  AAPL
# 2024-04-17  169.61  170.65  168.000  168.00   50901210  AAPL
# 2024-04-18  168.03  168.64  166.550  167.04   43122903  AAPL
#
# [2339 rows x 6 columns]

# %%
# Repeat the two previous steps for a few other stocks, always creating a new dataframe:
#  Tesla, IBM and Microsoft. (Ticker symbols TSLA, IBM and MSFT.)


api_key = "HFQZ62XLBEZQXFYT"

df_tesla = web.DataReader("TSLA", data_source="av-daily", api_key=api_key, start=start_date, end=end_date)
df_tesla["stock"] = "TSLA"

df_ibm = web.DataReader("IBM", data_source="av-daily", api_key=api_key, start=start_date, end=end_date)
df_ibm["stock"] = "IBM"

df_microsoft = web.DataReader("MSFT", data_source="av-daily", api_key=api_key, start=start_date, end=end_date)
df_microsoft["stock"] = "MSFT"

df_tesla
df_ibm
df_microsoft
# Out:
#               open      high       low    close    volume stock
# 2015-01-02   46.66   47.4200   46.5400   46.760  27913852  MSFT
# 2015-01-05   46.37   46.7300   46.2500   46.325  39673865  MSFT
# 2015-01-06   46.38   46.7490   45.5400   45.650  36447854  MSFT
# 2015-01-07   45.98   46.4600   45.4900   46.230  29114061  MSFT
# 2015-01-08   46.75   47.7499   46.7200   47.590  29645202  MSFT
# ...            ...       ...       ...      ...       ...   ...
# 2024-04-12  424.05  425.1794  419.7700  421.900  19253750  MSFT
# 2024-04-15  426.60  426.8200  413.4300  413.640  20273538  MSFT
# 2024-04-16  414.57  418.4000  413.7301  414.580  16765616  MSFT
# 2024-04-17  417.25  418.8800  410.3300  411.840  15855485  MSFT
# 2024-04-18  410.63  411.8900  403.9500  404.270  21029917  MSFT
#
# [2339 rows x 6 columns]

# %%
# Combine the four separate dataFrames into one combined dataFrame df that holds the information for all four stocks

df = pd.concat([df_apple, df_tesla, df_ibm, df_microsoft])
df
# Out:
#               open      high       low   close    volume stock
# 2015-01-02  111.39  111.4400  107.3500  109.33  53204626  AAPL
# 2015-01-05  108.29  108.6500  105.4100  106.25  64285491  AAPL
# 2015-01-06  106.54  107.4300  104.6300  106.26  65797116  AAPL
# 2015-01-07  107.20  108.2000  106.6950  107.75  40105934  AAPL
# 2015-01-08  109.23  112.1500  108.7000  111.89  59364547  AAPL
# ...            ...       ...       ...     ...       ...   ...
# 2024-04-12  424.05  425.1794  419.7700  421.90  19253750  MSFT
# 2024-04-15  426.60  426.8200  413.4300  413.64  20273538  MSFT
# 2024-04-16  414.57  418.4000  413.7301  414.58  16765616  MSFT
# 2024-04-17  417.25  418.8800  410.3300  411.84  15855485  MSFT
# 2024-04-18  410.63  411.8900  403.9500  404.27  21029917  MSFT
#
# [9356 rows x 6 columns]

# %%
#  Shift the stock column into the index (making it a multi-level index consisting of the ticker symbol and the date).
df = df.reset_index()

df.set_index(["stock", "index"], inplace=True)

df
# Out:
#                     open      high       low   close    volume
# stock index
# AAPL  2015-01-02  111.39  111.4400  107.3500  109.33  53204626
#       2015-01-05  108.29  108.6500  105.4100  106.25  64285491
#       2015-01-06  106.54  107.4300  104.6300  106.26  65797116
#       2015-01-07  107.20  108.2000  106.6950  107.75  40105934
#       2015-01-08  109.23  112.1500  108.7000  111.89  59364547
# ...                  ...       ...       ...     ...       ...
# MSFT  2024-04-12  424.05  425.1794  419.7700  421.90  19253750
#       2024-04-15  426.60  426.8200  413.4300  413.64  20273538
#       2024-04-16  414.57  418.4000  413.7301  414.58  16765616
#       2024-04-17  417.25  418.8800  410.3300  411.84  15855485
#       2024-04-18  410.63  411.8900  403.9500  404.27  21029917
#
# [9356 rows x 5 columns]

# %%
# Create a dataFrame called vol, with the volume values.

vol = df["volume"]

vol
# Out:
# index
# 2015-01-02    53204626
# 2015-01-05    64285491
# 2015-01-06    65797116
# 2015-01-07    40105934
# 2015-01-08    59364547
#                 ...
# 2024-04-12    19253750
# 2024-04-15    20273538
# 2024-04-16    16765616
# 2024-04-17    15855485
# 2024-04-18    21029917
# Name: volume, Length: 9356, dtype: int64

# %%
# Aggregate the data of volume to weekly.
# Hint: Be careful to not sum data from the same week of 2015 and other years.

vol = df["volume"]

# Convert the index to datetime
vol.index = pd.to_datetime(vol.index)

# Resample the data weekly, taking the sum of the volume for each week.
vol_weekly = vol.resample("W").sum()

# Print the vol_weekly DataFrame
vol_weekly
# Out:
# index
# 2015-01-04     91408262
# 2015-01-11    488527205
# 2015-01-18    515385976
# 2015-01-25    383535971
# 2015-02-01    952276986
#                 ...
# 2024-03-24    900392278
# 2024-03-31    673241989
# 2024-04-07    869061950
# 2024-04-14    867145860
# 2024-04-21    704867051
# Freq: W-SUN, Name: volume, Length: 486, dtype: int64

# %%
# Find all the volume traded in the year of 2015
vol.index = pd.to_datetime(vol.index)

vol_2015 = vol[vol.index.year == 2015]

# Calculate the total volume traded in 2015
total_volume_2015 = vol_2015.sum()

# Print the result
print(f"Total volume traded in 2015: {total_volume_2015}")
# Out:
# Total volume traded in 2015: 24314152987
