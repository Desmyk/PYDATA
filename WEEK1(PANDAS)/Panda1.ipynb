# %% [markdown]
# <a href="https://colab.research.google.com/github/Desmyk/PYDATA/blob/main/panda1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import necessary lib
import pandas as pd

# %%
# Create a data dictionary that looks like the DataFrame below

dict = {'name':["USIU", "UON", "Havard", "Columbia"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}

df = pd.DataFrame(dict)

df
# Out:
#        name  degree  score
# 0      USIU     MBA     90
# 1       UON     BCA     40
# 2    Havard  M.Tech     80
# 3  Columbia     MBA     98

# %%
# Assign it to a variable called pokemon

pokemon = pd.Series(dict)
pokemon
# Out:
# name      [USIU, UON, Havard, Columbia]
# degree          [MBA, BCA, M.Tech, MBA]
# score                  [90, 40, 80, 98]
# dtype: object

# %%
raw_data = {"name": ['Bulbasaur', 'Charmander','Squirtle','Caterpie'],
            "evolution": ['Ivysaur','Charmeleon','Wartortle','Metapod'],
            "type": ['grass', 'fire', 'water', 'bug'],
            "hp": [45, 39, 44, 45],
            "pokedex": ['yes', 'no','yes','no']
            }

df = pd.DataFrame(raw_data)
df
# Out:
#          name   evolution   type  hp pokedex
# 0   Bulbasaur     Ivysaur  grass  45     yes
# 1  Charmander  Charmeleon   fire  39      no
# 2    Squirtle   Wartortle  water  44     yes
# 3    Caterpie     Metapod    bug  45      no

# %%
# Step 4. Ops...it seems the DataFrame columns are in alphabetical order.
# Place the order of the columns as name, type, hp, evolution, pokedex

pokemon1 = pd.DataFrame.from_dict(raw_data)
pokemon1 = pokemon1[["name", "type", "hp", "evolution", "pokedex"]]
pokemon1
# Out:
#          name   type  hp   evolution pokedex
# 0   Bulbasaur  grass  45     Ivysaur     yes
# 1  Charmander   fire  39  Charmeleon      no
# 2    Squirtle  water  44   Wartortle     yes
# 3    Caterpie    bug  45     Metapod      no

# %%
# Add another column called place, and insert what you have in mind

place = ["Desert", "Pool", "Market", "park"]
pokemon1["Place"] = place
pokemon1
# Out:
#          name   type  hp   evolution pokedex   Place
# 0   Bulbasaur  grass  45     Ivysaur     yes  Desert
# 1  Charmander   fire  39  Charmeleon      no    Pool
# 2    Squirtle  water  44   Wartortle     yes  Market
# 3    Caterpie    bug  45     Metapod      no    park

# %%
# Present the type of each column

pokemon1.dtypes
# Out:
# name         object
# type         object
# hp            int64
# evolution    object
# pokedex      object
# dtype: object

# %%
# get hp and evolutin for row 2 amd 3

data = pokemon1.loc[2:3, ["hp", "evolution"]]
print(data)
# Out:
#    hp  evolution
# 2  44  Wartortle
# 3  45    Metapod

# %%
# Get the place for row 3
place = pokemon1.loc[3, "Place"]

# Print the result
print("Place for row 3:", place)
# Out:
# Place for row 3: park
