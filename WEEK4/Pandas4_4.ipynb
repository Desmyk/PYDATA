# %% [markdown]
# <a href="https://colab.research.google.com/github/Desmyk/PYDATA/blob/main/Pandas4_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the necessary libraries
import pandas as pd
import numpy as np

# %%
# import dataset and Assign it to a variable called baby_names.

baby_names = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv')
baby_names.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016395 entries, 0 to 1016394
# Data columns (total 7 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1016395 non-null  int64
#  1   Id          1016395 non-null  int64
#  2   Name        1016395 non-null  object
#  3   Year        1016395 non-null  int64
#  4   Gender      1016395 non-null  object
#  5   State       1016395 non-null  object
#  6   Count       1016395 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 54.3+ MB

# %%
# See the first 10 entries

baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %%
# Delete the column 'Unnamed: 0' and 'Id'
# deletes Unnamed: 0
del baby_names['Unnamed: 0']

# deletes Unnamed: 0
del baby_names['Id']

baby_names.head()
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %%
# Are there more male or female names in the dataset?

baby_names['Gender'].value_counts()
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %%
# Group the dataset by name and assign to names

# group the data
names = baby_names.groupby("Name")

names.head()
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1004923  Gryffin  2014      M    WI      5
# 1004950     Kroy  2014      M    WI      5
# 1004973     Owyn  2014      M    WI      5
# 1005707   Haylea  2005      F    WV      5
# 1012216  Coalton  2012      M    WV      7
#
# [65502 rows x 5 columns]

# %%
# How many different names exist in the dataset?

len(names)
# Out:
# 17632

# %%
# What is the name with most occurrences?

names.Count.idxmax()
# Out:
# Name
# Aaban      693699
# Aadan      120728
# Aadarsh    323950
# Aaden      121886
# Aadhav     138429
#             ...
# Zyra       884656
# Zyrah      881583
# Zyren      910625
# Zyria      237366
# Zyriah     862166
# Name: Count, Length: 17632, dtype: int64

# %%
# How many different names have the least occurrences?

min_count = names["Count"].min()
min_count
#least = names[names["Count"] == min_count]
#num_least = len(least)
#num_least
# Out:
# Name
# Aaban      6
# Aadan      5
# Aadarsh    5
# Aaden      5
# Aadhav     6
#           ..
# Zyra       5
# Zyrah      5
# Zyren      6
# Zyria      5
# Zyriah     5
# Name: Count, Length: 17632, dtype: int64

# %%
# What is the median name occurrence?

names["Count"].median()
# Out:
# Name
# Aaban       6.0
# Aadan       5.5
# Aadarsh     5.0
# Aaden      10.0
# Aadhav      6.0
#            ...
# Zyra        6.0
# Zyrah       5.5
# Zyren       6.0
# Zyria       6.0
# Zyriah      6.0
# Name: Count, Length: 17632, dtype: float64

# %%
# What is the standard deviation of names?

names.Count.std()
# Out:
# Name
# Aaban       0.000000
# Aadan       0.957427
# Aadarsh          NaN
# Aaden      21.154974
# Aadhav           NaN
#              ...
# Zyra        1.154701
# Zyrah       0.707107
# Zyren            NaN
# Zyria       0.737865
# Zyriah      1.666667
# Name: Count, Length: 17632, dtype: float64

# %%
# Get a summary with the mean, min, max, std and quartiles.

names.describe()
# Out:
#           Year                                                           \
#          count         mean       std     min      25%     50%      75%
# Name
# Aaban      2.0  2013.500000  0.707107  2013.0  2013.25  2013.5  2013.75
# Aadan      4.0  2009.750000  2.872281  2008.0  2008.00  2008.5  2010.25
# Aadarsh    1.0  2009.000000       NaN  2009.0  2009.00  2009.0  2009.00
# Aaden    196.0  2010.015306  2.044322  2005.0  2008.00  2010.0  2011.00
# Aadhav     1.0  2014.000000       NaN  2014.0  2014.00  2014.0  2014.00
# ...        ...          ...       ...     ...      ...     ...      ...
# Zyra       7.0  2012.142857  2.115701  2008.0  2011.50  2013.0  2013.50
# Zyrah      2.0  2012.000000  1.414214  2011.0  2011.50  2012.0  2012.50
# Zyren      1.0  2013.000000       NaN  2013.0  2013.00  2013.0  2013.00
# Zyria     10.0  2008.900000  2.685351  2005.0  2007.25  2008.0  2010.50
# Zyriah     9.0  2009.666667  2.915476  2006.0  2007.00  2009.0  2012.00
#
#                  Count
# ...
